# %%
def get_vocabulary_from_arpa(arpa_path):
    vocabulary = set()

    with open(arpa_path, 'r', encoding='utf-8') as arpa_file:
        in_data_section = False

        for line in arpa_file:
            line = line.strip()

            if line == '\\data\\':
                in_data_section = True
            elif line.startswith('\\') and in_data_section:
                break  # End of data section
            elif not line.startswith('\\') and in_data_section:
                # Inside the n-gram section, extract vocabulary
                parts = line.split()
                if len(parts) > 1:
                    word = parts[1]
                    vocabulary.add(word)

    return vocabulary

def add_tokens_to_arpa(arpa_path, tokens_to_add, tokens_to_exclude):
    with open(arpa_path, 'r', encoding='utf-8') as arpa_file:
        arpa_content = arpa_file.readlines()

    # Find the index where the unigram section starts
    start_index = arpa_content.index('\\1-grams:\n') + 1

    # Insert entries for the new tokens excluding the ones to exclude
    for token in tokens_to_add:
        if token not in tokens_to_exclude:
            arpa_content.insert(start_index, f'-99.999 {token} -99.999\n')

    # Write the modified content back to the ARPA file
    with open(arpa_path, 'w', encoding='utf-8') as arpa_file:
        arpa_file.writelines(arpa_content)

# %%
def convert_numbers_to_words(text):
    words = []
    for word in text.split():
        if word.isdigit():
            # Convert numbers to words
            word = num2words(word)
        elif re.match(r'\d+(st|nd|rd|th)', word):
            # Handle ordinal numbers
            number_part = re.match(r'\d+', word).group()
            ordinal_suffix = re.search(r'(st|nd|rd|th)', word).group()
            word = num2words(number_part, ordinal=True) + ordinal_suffix
        words.append(word)
    return ' '.join(words)

def remove_punctuation_and_special_characters(text):
    # Remove punctuation and special characters
    return re.sub(r'[^\w\s,-]', '', text)

# %%
# !pip install jiwer
# !pip install evaluate 
# !pip install pyctcdecode
# !pip install torch
# !pip install g2p
# !pip install num2words
# Out:
# Collecting num2words
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 6.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=6356b80115ff58b5688756d95fccaab0ffdeef2243b8fb7d127200c10dec1516
#   Stored in directory: /home/osx/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.13

# %%
from datasets import DatasetDict, Dataset, Audio
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC, Wav2Vec2ProcessorWithLM
# from pyctcdecode import build_ctcdecoder
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union
from tqdm import tqdm
from evaluate import load

# %%
# !pip install g2p num2words
# Out:
# WARNING: Ignoring invalid distribution -illow (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mdet (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-nvjitlink-cu12 (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# Collecting g2p
#   Obtaining dependency information for g2p from https://files.pythonhosted.org/packages/c8/2c/4c0c30c92e4647bce762b3cd1397c4ab8119a514a9a58f2211be358ee0e6/g2p-1.1.20230822-py3-none-any.whl.metadata
#   Downloading g2p-1.1.20230822-py3-none-any.whl.metadata (16 kB)
# Collecting num2words
#   Obtaining dependency information for num2words from https://files.pythonhosted.org/packages/8f/f0/ca1228af2bcbce2fdf2b23d58643c84253b88a3c1cd9dba391ca683c4b21/num2words-0.5.13-py3-none-any.whl.metadata
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: openpyxl in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (3.0.10)
# Requirement already satisfied: click>=8.0.4 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (8.1.7)
# Collecting coloredlogs<=14.0 (from g2p)
#   Downloading coloredlogs-14.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 1.0 MB/s eta 0:00:00
# Collecting dnspython<=2.3.0,>=2.1.0 (from g2p)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 3.8 MB/s eta 0:00:0000:01
# Collecting eventlet>=0.33.0 (from g2p)
#   Obtaining dependency information for eventlet>=0.33.0 from https://files.pythonhosted.org/packages/44/d2/2f3da64a54d247b8504f644a42163deb5d28b3c57719eb6acc9932734c20/eventlet-0.35.1-py3-none-any.whl.metadata
#   Downloading eventlet-0.35.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting flask-cors>=3.0.9 (from g2p)
#   Obtaining dependency information for flask-cors>=3.0.9 from https://files.pythonhosted.org/packages/10/69/1e6cfb87117568a9de088c32d6258219e9d1ff7c131abf74249ef2031279/Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting flask-talisman>=0.7.0 (from g2p)
#   Obtaining dependency information for flask-talisman>=0.7.0 from https://files.pythonhosted.org/packages/77/1c/a15ac936dc3ae4491c5ff089dccdccd72cd3608b15fcf4e2de961f9ee8f3/flask_talisman-1.1.0-py2.py3-none-any.whl.metadata
#   Downloading flask_talisman-1.1.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting flask-restful>=0.3.9 (from g2p)
#   Obtaining dependency information for flask-restful>=0.3.9 from https://files.pythonhosted.org/packages/d7/7b/f0b45f0df7d2978e5ae51804bb5939b7897b2ace24306009da0cc34d8d1f/Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata
#   Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting networkx<=2.8.4,>=2.5 (from g2p)
#   Downloading networkx-2.8.4-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.3 MB/s eta 0:00:0000:0100:01
# Collecting panphon>=0.19 (from g2p)
#   Downloading panphon-0.20.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.2 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (6.0.1)
# Requirement already satisfied: regex in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (2023.12.25)
# Requirement already satisfied: requests in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (2.28.2)
# Requirement already satisfied: tqdm in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (4.65.2)
# Requirement already satisfied: text-unidecode in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (1.3)
# Collecting Flask==2.2.5 (from g2p)
#   Obtaining dependency information for Flask==2.2.5 from https://files.pythonhosted.org/packages/9f/1a/8b6d48162861009d1e017a9740431c78d860809773b66cac220a11aa3310/Flask-2.2.5-py3-none-any.whl.metadata
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: werkzeug==2.2.3 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from g2p) (2.2.3)
# Collecting flask-socketio>=5.0.0 (from g2p)
#   Obtaining dependency information for flask-socketio>=5.0.0 from https://files.pythonhosted.org/packages/56/c8/dc0be9e26272dc89342868ecc2d9ddb9e31002b4b8e49fdb754aa0f9ecbf/Flask_SocketIO-5.3.6-py3-none-any.whl.metadata
#   Downloading Flask_SocketIO-5.3.6-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-engineio>=4.0.0 (from g2p)
#   Obtaining dependency information for python-engineio>=4.0.0 from https://files.pythonhosted.org/packages/fe/e5/03fa8e76c718e1dd7fb5b74e9ce816ae0e08734080b1e98dbafbcf2fc8ba/python_engineio-4.9.0-py3-none-any.whl.metadata
#   Downloading python_engineio-4.9.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-socketio>=5.0.0 (from g2p)
#   Obtaining dependency information for python-socketio>=5.0.0 from https://files.pythonhosted.org/packages/06/50/1dc8262920f10e2f94376295fe4c6c7237d5dfadbf34365f403e24727345/python_socketio-5.11.1-py3-none-any.whl.metadata
#   Downloading python_socketio-5.11.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Jinja2>=3.0 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from Flask==2.2.5->g2p) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from Flask==2.2.5->g2p) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from werkzeug==2.2.3->g2p) (2.1.3)
# Collecting docopt>=0.6.2 (from num2words)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting humanfriendly>=7.1 (from coloredlogs<=14.0->g2p)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.3 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: greenlet>=1.0 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from eventlet>=0.33.0->g2p) (2.0.1)
# Collecting aniso8601>=0.82 (from flask-restful>=0.3.9->g2p)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 855.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.3.0 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from flask-restful>=0.3.9->g2p) (1.16.0)
# Requirement already satisfied: pytz in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from flask-restful>=0.3.9->g2p) (2023.3.post1)
# Requirement already satisfied: setuptools in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from panphon>=0.19->g2p) (60.2.0)
# Collecting unicodecsv (from panphon>=0.19->g2p)
#   Using cached unicodecsv-0.14.1-py3-none-any.whl
# Requirement already satisfied: numpy>=1.20.2 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from panphon>=0.19->g2p) (1.23.5)
# Collecting editdistance (from panphon>=0.19->g2p)
#   Obtaining dependency information for editdistance from https://files.pythonhosted.org/packages/c2/fb/2940d26ebda12efd280ae939436f17ac482930d862df9e774cb8b771ab03/editdistance-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading editdistance-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: munkres in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from panphon>=0.19->g2p) (1.1.4)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.0.0->g2p)
#   Obtaining dependency information for simple-websocket>=0.10.0 from https://files.pythonhosted.org/packages/6d/ea/288a8ac1d9551354488ff60c0ac6a76acc3b6b60f0460ac1944c75e240da/simple_websocket-1.0.0-py3-none-any.whl.metadata
#   Downloading simple_websocket-1.0.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting bidict>=0.21.0 (from python-socketio>=5.0.0->g2p)
#   Obtaining dependency information for bidict>=0.21.0 from https://files.pythonhosted.org/packages/53/34/4ef69a52e91b204efd6d1dd6e4b11504a309f7b83bcc5c39b55d8cb4b577/bidict-0.23.0-py3-none-any.whl.metadata
#   Downloading bidict-0.23.0-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: et_xmlfile in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from openpyxl->g2p) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from requests->g2p) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from requests->g2p) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from requests->g2p) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from requests->g2p) (2023.7.22)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.0.0->g2p)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: h11<1,>=0.9.0 in /work/van-speech-nlp/jenv/lib/python3.10/site-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.0.0->g2p) (0.14.0)
# Downloading g2p-1.1.20230822-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.1 MB/s eta 0:00:0000:0100:01
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 2.7 MB/s eta 0:00:00ta 0:00:01
# Downloading eventlet-0.35.1-py3-none-any.whl (359 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.8/359.8 kB 6.4 MB/s eta 0:00:00:00:01
# Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Downloading Flask_RESTful-0.3.10-py2.py3-none-any.whl (26 kB)
# Downloading Flask_SocketIO-5.3.6-py3-none-any.whl (18 kB)
# Downloading flask_talisman-1.1.0-py2.py3-none-any.whl (18 kB)
# Downloading python_engineio-4.9.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Downloading python_socketio-5.11.1-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# Downloading bidict-0.23.0-py3-none-any.whl (32 kB)
# Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Downloading editdistance-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 6.3 MB/s eta 0:00:00:00:01
# WARNING: Ignoring invalid distribution -illow (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -mdet (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-nvjitlink-cu12 (/work/van-speech-nlp/jenv/lib/python3.10/site-packages)
# Installing collected packages: unicodecsv, flask-talisman, docopt, aniso8601, wsproto, num2words, networkx, humanfriendly, editdistance, dnspython, bidict, simple-websocket, panphon, Flask, eventlet, coloredlogs, python-engineio, flask-restful, flask-cors, python-socketio, flask-socketio, g2p
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 2.4.2
#     Uninstalling dnspython-2.4.2:
#       Successfully uninstalled dnspython-2.4.2
#   Attempting uninstall: Flask
#     Found existing installation: Flask 2.2.2
#     Uninstalling Flask-2.2.2:
#       Successfully uninstalled Flask-2.2.2
# Successfully installed Flask-2.2.5 aniso8601-9.0.1 bidict-0.23.0 coloredlogs-14.0 dnspython-2.3.0 docopt-0.6.2 editdistance-0.8.1 eventlet-0.35.1 flask-cors-4.0.0 flask-restful-0.3.10 flask-socketio-5.3.6 flask-talisman-1.1.0 g2p-1.1.20230822 humanfriendly-10.0 networkx-2.8.4 num2words-0.5.13 panphon-0.20.0 python-engineio-4.9.0 python-socketio-5.11.1 simple-websocket-1.0.0 unicodecsv-0.14.1 wsproto-1.2.0
