# %%
# !pip install num2words
from datasets import load_dataset
#from g2p_en import G2p
from g2p import make_g2p
from num2words import num2words  # Import num2words from nltk
import re

# Load the Tatoeba dataset
tatoeba_dataset = load_dataset("tatoeba", 'en-mr')

# Initialize g2p converter
transducer = make_g2p('eng', 'eng-arpabet')

# %%
# Function to convert numbers to words
def convert_numbers_to_words(text):
    words = []
    for word in text.split():
        if word.isdigit():
            # Convert numbers to words
            word = num2words(word)
        elif re.match(r'\d+(st|nd|rd|th)', word):
            # Handle ordinal numbers
            number_part = re.match(r'\d+', word).group()
            ordinal_suffix = re.search(r'(st|nd|rd|th)', word).group()
            word = num2words(number_part, ordinal=True) + ordinal_suffix
        words.append(word)
    return ' '.join(words)

def remove_punctuation_and_special_characters(text):
    # Remove punctuation and special characters
    return re.sub(r'[^\w\s,-]', '', text)

# %%
translations = tatoeba_dataset["train"]["translation"]
for translation in translations[:1]:
  sentence = translation["en"]
  print(sentence)
  sentence = remove_punctuation_and_special_characters(sentence)
  print(sentence)
  sentence = convert_numbers_to_words(sentence)
  print(sentence)
  phonemes_list = [transducer(word).output_string for word in re.findall(r'\S+', sentence)]
  print(phonemes_list)
  all_phonemes = [item for sublist in phonemes_list for item in sublist.split()]
  print(all_phonemes)
  # Replace hyphens with letters that come after the hyphen
  all_phonemes_no_hyphen = [phoneme.split("-")[-1] if "-" in phoneme else phoneme for phoneme in all_phonemes]
  print(all_phonemes_no_hyphen)
# Out:
# Today is June 18th and it is Muiriel's birthday!
# Today is June 18th and it is Muiriels birthday
# Today is June eighteenthth and it is Muiriels birthday
# ['T AH D EY ', 'IH Z ', 'JH UW N ', '', 'AH N D ', 'IH T ', 'IH Z ', '', 'B ER TH D EY ']
# ['T', 'AH', 'D', 'EY', 'IH', 'Z', 'JH', 'UW', 'N', 'AH', 'N', 'D', 'IH', 'T', 'IH', 'Z', 'B', 'ER', 'TH', 'D', 'EY']
# ['T', 'AH', 'D', 'EY', 'IH', 'Z', 'JH', 'UW', 'N', 'AH', 'N', 'D', 'IH', 'T', 'IH', 'Z', 'B', 'ER', 'TH', 'D', 'EY']

# %%
unique_phonemes = set()

with open("/work/van-speech-nlp/jindaznb/jslpnb/torgo_inference_on_cluster/dataset_phonemes.txt", "w") as file:
    for translation in translations:
      sentence = translation["en"]
      sentence = remove_punctuation_and_special_characters(sentence)
      sentence = convert_numbers_to_words(sentence)
      phonemes_list = [transducer(word).output_string for word in re.findall(r'\S+', sentence)]
      all_phonemes = [item for sublist in phonemes_list for item in sublist.split()]

      # Update the set of unique phonemes excluding those containing hyphens
      unique_phonemes.update(phoneme for phoneme in all_phonemes if "-" not in phoneme)

      # Replace hyphens with letters that come after the hyphen
      all_phonemes_no_hyphen = [phoneme.split("-")[-1] if "-" in phoneme else phoneme for phoneme in all_phonemes]

      # Write all individual phonemes (without hyphens) to the file
      file.write(" ".join(all_phonemes_no_hyphen))
      file.write("\n")

# Print the vocabulary of phonemes
print("Phoneme Vocabulary:")
print(unique_phonemes)
# Out:
# Phoneme Vocabulary:
# {'ZH', 'AE', 'NG', ',,', 'IH', ',', 'TH', 'ER', 'R', 'M', 'HH', 'D', 'AY', 'DH', 'Z', 'W', 'AO', 'JH', 'Y', 'UH', 'G', 'AA', 'EH', 'F', 'P', 'S', 'N', 'OW', 'T', 'CH', ',,,', 'AW', 'SH', 'EY', 'IY', 'UW', 'AH', 'B', 'L', 'V', 'K', 'OY'}

# %%
# Read the content from the file
with open("dataset_phonemes.txt", 'r') as file:
    content = file.read()

# Remove instances of consecutive triple commas (,,,)
content = content.replace(',,,', '')
print(content)
# Remove instances of consecutive double commas (,,)
content = content.replace(',,', '')

# Remove individual commas
content = content.replace(',', '')
# Write the modified content back to the file
with open('dataset_phonemes.txt', 'w') as file:
    file.write(content)
# Out:
# T AH D EY IH Z JH UW N AH N D IH T IH Z B ER TH D EY
# IH Z T W EH N T IY N AW
# DH AH P AE S W ER D IH Z
# AY W IH L B IY B AE K S UW N
# AY W IH L B IY B AE K S UW N
# IH M AE T AH L AO S F AO R W ER D Z
# IH M AE T AH L AO S F AO R W ER D Z
# DH IH S IH Z N EH V ER G OW IH NG T UW EH N D
# DH IH S IH Z N EH V ER G OW IH NG T UW EH N D
# DH IH S IH Z N EH V ER G OW IH NG T UW EH N D
# AY W AA Z IH N DH AH M AW N T AH N Z
# AY W AA Z IH N DH AH M AW N T AH N Z
# Y UW AA R IH N M AY W EY
# Y UW AA R IH N M AY W EY
# AY M EY K W AH N HH AH N D R AH D AH D EY
# AY M EY K W AH N HH AH N D R AH D AH D EY
# AY M EY K W AH N HH AH N D R AH D AH D EY
# DH AE T W OW N T HH AE P AH N
# DH AE T W OW N T HH AE P AH N
# DH AE T W OW N T HH AE P AH N
# AY M IH S Y UW
# AY M IH S Y UW
# IH L K AO L DH EH M T AH M AA R OW W EH N AY K AH M B AE K
# Y UW SH UH D S L IY P
# Y UW SH UH D S L IY P
# IH M G OW IH NG T UW G OW
# AY K AE N T L AY V DH AE T K AY N D AH V L AY F
# M OW S T P IY P AH L TH IH NG K IH M K R EY Z IY
# M OW S T P IY P AH L TH IH NG K IH M K R EY Z IY
# M OW S T P IY P AH L TH IH NG K IH M K R EY Z IY
# N OW IH M N AA T Y UW AA R
# M AY L AY N
# M AY L AY N
# M AY L AY N
# K IH K IH NG M IY
# K IH K IH NG M IY
# K IH K IH NG M IY
# AA R Y UW SH UH R
# AA R Y UW SH UH R
# IH T S ER P R AY Z M IY
# W EH N AY G R OW AH P , AY W AA N T T UW B IY AH K IH NG
# IH M S OW F AE T
# IH M S OW F AE T
# S OW W AH T
# S OW W AH T
# S OW W AH T
# IH M G AA N AH SH UW T HH IH M
# B IH K AO Z AH G ER L
# AY M EY B IY AE N T IH S OW SH AH L , B AH T IH T M IY N AY T AO K T UW P IY P AH L
# M OW S T P IY P AH L R AY T AH B AW T DH EH R D EY L IY L AY F
# HH AW L AO NG D IH D Y UW S T EY
# HH AW L AO NG D IH D Y UW S T EY
# HH AW L AO NG D IH D Y UW S T EY
# HH AW L AO NG D IH D Y UW S T EY
# HH AW L AO NG D IH D Y UW S T EY
# HH AW L AO NG D IH D Y UW S T EY
# W AH T S M EH R IY S EH L IH NG
# L ER N IH T B AY M EH M ER AY Z IH NG T R AY T UW AH N D ER S T AE N D IH T
# L ER N IH T B AY M EH M ER AY Z IH NG T R AY T UW AH N D ER S T AE N D IH T
# Y AE N IY AO L W EY Z S K R AE CH AH Z HH IH Z B AH T
# Y UW N IY D AH L AA T AH V M AH N IY T UW G OW T UW DH IH S S K UW L
# IY T AH S
# IY T AH S
# AY L AY K L IH S AH N IH NG T UW JH AE P AH N IY Z M Y UW Z IH K
# T AA M W AA Z T OW T AH L IY N EY K AH D
# DH AH F AO R AH M W AA Z M UW V D T UW AH N UW S ER V ER
# IH T S N AA T F UH L
# IH T S N AA T F UH L
# Y AE N IY R OW T AE N EH S EY
# Y AE N IY S L AE P T S K UH R AA AA N DH AH B AH T
# W EH R D IH D Y AE N IY D UW DH AE T
# Y AE N IY S EH D HH IY S M EH L T G AE S
# Y AE N IY W AA Z TH IH NG K IH NG
# Y AE N IY L AH V Z K IH D Z
# N AA T W AH T IH M T AO K IH NG AH B AW T
# N AA T W AH T IH M T AO K IH NG AH B AW T
# AE D M IY AA N F EY S B UH K IH F Y UW W AA N T M AY N EY M DH EH R IH Z
# F ER G IH V M IY G AA D F ER G IH V Z
# F ER G IH V M IY G AA D F ER G IH V Z
# Y AE N IY IH Z AH L AY ER
# K AE N W IY M EY K AE L JH IH R IY AH AH R IH CH K AH N T R IY
# K AE N W IY M EY K AE L JH IH R IY AH AH R IH CH K AH N T R IY
# AE L JH IH R IY AH SH UH D B IY DH AH L AA R JH AH S T IH K AA N AH M IY IH N N AO R TH AE F R AH K AA

# %%
import os
from huggingface_hub import Repository


input_dataset = "dataset_phonemes.txt"
output_directory = "output_directory/"
output_model_base = "output_model.klm"

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Ngram size options
order_trigram = 3
order_unigram = 1

trigram_repo = Repository(local_dir="output_model.klm_trigram", clone_from="laurynflu/output_model.klm_trigram")
# Out:
# /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/repository.py:591, in Repository.check_git_versions(self)
#     590 try:
# --> 591     lfs_version = run_subprocess("git-lfs --version", self.local_dir).stdout.strip()
#     592 except FileNotFoundError:
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/utils/_subprocess.py:83, in run_subprocess(command, folder, check, **kwargs)
#      81     folder = str(folder)
# ---> 83 return subprocess.run(
#      84     command,
#      85     stderr=subprocess.PIPE,
#      86     stdout=subprocess.PIPE,
#      87     check=check,
#      88     encoding="utf-8",
#      89     errors="replace",  # if not utf-8, replace char by �
#      90     cwd=folder or os.getcwd(),
#      91     **kwargs,
#      92 )
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/subprocess.py:1863, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1862         err_msg = os.strerror(errno_num)
# -> 1863     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'git-lfs'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 17
#      14 order_trigram = 3
#      15 order_unigram = 1
# ---> 17 trigram_repo = Repository(local_dir="output_model.klm_trigram", clone_from="laurynflu/output_model.klm_trigram")
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:118, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     115 if check_use_auth_token:
#     116     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 118 return fn(*args, **kwargs)
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/utils/_deprecation.py:132, in _deprecate_method.<locals>._inner_deprecate_method.<locals>.inner_f(*args, **kwargs)
#     130     warning_message += " " + message
#     131 warnings.warn(warning_message, FutureWarning)
# --> 132 return f(*args, **kwargs)
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/repository.py:521, in Repository.__init__(self, local_dir, clone_from, repo_type, token, git_user, git_email, revision, skip_lfs_files, client)
#     518 self.skip_lfs_files = skip_lfs_files
#     519 self.client = client if client is not None else HfApi()
# --> 521 self.check_git_versions()
#     523 if isinstance(token, str):
#     524     self.huggingface_token: Optional[str] = token
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/huggingface_hub/repository.py:593, in Repository.check_git_versions(self)
#     591     lfs_version = run_subprocess("git-lfs --version", self.local_dir).stdout.strip()
#     592 except FileNotFoundError:
# --> 593     raise EnvironmentError(
#     594         "Looks like you do not have git-lfs installed, please install."
#     595         " You can install from https://git-lfs.github.com/."
#     596         " Then run `git lfs install` (you only have to do this once)."
#     597     )
#     598 logger.info(git_version + "\n" + lfs_version)
#
# OSError: Looks like you do not have git-lfs installed, please install. You can install from https://git-lfs.github.com/. Then run `git lfs install` (you only have to do this once).

# %%
# !module load git/2.19.0

# %%
# !kenlm/build/bin/lmplz -o 3    --text dataset_phonemes.txt     --arpa output_directory/output_model.klm_trigram.arpa     --discount_fallback --skip_symbols|     kenlm/build/bin/build_binary     -T /dev/stdin /output_directory/output_model.klm_trigram.arpa

# %%
def get_vocabulary_from_arpa(arpa_path):
    vocabulary = set()

    with open(arpa_path, 'r', encoding='utf-8') as arpa_file:
        in_data_section = False

        for line in arpa_file:
            line = line.strip()

            if line == '\\data\\':
                in_data_section = True
            elif line.startswith('\\') and in_data_section:
                break  # End of data section
            elif not line.startswith('\\') and in_data_section:
                # Inside the n-gram section, extract vocabulary
                parts = line.split()
                if len(parts) > 1:
                    word = parts[1]
                    vocabulary.add(word)

    return vocabulary

# Replace with the actual path to your KenLM ARPA file
arpa_path = "output_directory/output_model.klm_trigram.arpa"
vocabulary = get_vocabulary_from_arpa(arpa_path)

# Print or use the vocabulary as needed
print("Vocabulary:", vocabulary)

# %%
def add_tokens_to_arpa(arpa_path, tokens_to_add, tokens_to_exclude):
    with open(arpa_path, 'r', encoding='utf-8') as arpa_file:
        arpa_content = arpa_file.readlines()

    # Find the index where the unigram section starts
    start_index = arpa_content.index('\\1-grams:\n') + 1

    # Insert entries for the new tokens excluding the ones to exclude
    for token in tokens_to_add:
        if token not in tokens_to_exclude:
            arpa_content.insert(start_index, f'-99.999 {token} -99.999\n')

    # Write the modified content back to the ARPA file
    with open(arpa_path, 'w', encoding='utf-8') as arpa_file:
        arpa_file.writelines(arpa_content)

# Replace with the actual path to your KenLM ARPA file
arpa_path = "output_directory/output_model.klm_trigram.arpa"

# Tokens to add
new_tokens = ["<pad>", "<sil>", "<spn>"]

# Tokens to exclude
tokens_to_exclude = ["<s>", "</s>"]

# Add tokens to the ARPA file excluding the specified tokens
add_tokens_to_arpa(arpa_path, new_tokens, tokens_to_exclude)

# %%
# Replace with the actual path to your KenLM ARPA file
arpa_path = "output_directory/output_model.klm_trigram.arpa"
vocabulary = get_vocabulary_from_arpa(arpa_path)

# Print or use the vocabulary as needed
print("Vocabulary:", vocabulary)

# %%
# Debugging: Print the current working directory
print("Current working directory:", os.getcwd())
output_directory = "output_directory/"

# Change the working directory
os.chdir(output_directory)

# Verify the change
new_dir = os.getcwd()
print("New working directory:", new_dir)


# Debugging: Print the contents of the local directory
print("Contents of the local directory:", os.listdir("."))

# Push to Hugging Face
trigram_repo.push_to_hub(commit_message="Create trigram model with kenLM")

# %%
# !kenlm/build/bin/build_binary output_directory/output_model.klm_trigram.arpa output_directory/output_model.klm_trigram.bin

# %%
from pycorrector import EnSpellCorrector
# Out:
# /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
    # 1. 演示英文句子纠错
    sent = "what happending? how to speling it, can you gorrect it?"
    m = EnSpellCorrector()
    details = m.correct(sent)
    print(details)
    print()
# Out:
# 2024-02-15 23:21:21.535 | DEBUG    | pycorrector.en_spell_corrector:__init__:53 - load en spell data: /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/data/en.json.gz, size: 30120
# {'source': 'what happending? how to speling it, can you gorrect it?', 'target': 'what happening? how to spelling it, can you correct it?', 'errors': [('happending', 'happening', 5), ('speling', 'spelling', 24), ('gorrect', 'correct', 44)]}

# %%
    sent = "what is your name? shylock?"
    r = m.correct(sent)
    print(r)
    print('-' * 42)
    my_dict = {'your': 120, 'name': 2, 'is': 1, 'shylock': 1, 'what': 1}  # word, freq
    spell = EnSpellCorrector(word_freq_dict=my_dict)
    r = spell.correct(sent)
    print(r)
    print()
# Out:
# {'source': 'what is your name? shylock?', 'target': 'what is your name? shock?', 'errors': [('shylock', 'shock', 19)]}
# ------------------------------------------
# {'source': 'what is your name? shylock?', 'target': 'what is your name? shylock?', 'errors': []}

# %%
from pycorrector import EnSpellCorrector
m = EnSpellCorrector("output_directory/output_model.klm_trigram.bin")
m
sent = "what is your name? shylock?"
r = m.correct(sent)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       3 m
#       4 sent = "what is your name? shylock?"
# ----> 5 r = m.correct(sent)
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/en_spell_corrector.py:165, in EnSpellCorrector.correct(self, sentence, include_symbol)
#     163     corrected_item = self.custom_confusion_dict[w]
#     164 else:
# --> 165     corrected_item = self.correct_word(w)
#     166 if corrected_item != w:
#     167     begin_idx = idx
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/en_spell_corrector.py:112, in EnSpellCorrector.correct_word(self, word)
#     105 def correct_word(self, word):
#     106     """
#     107     most probable spelling correction for word
#     108     :param word:
#     109     :param mini_prob:
#     110     :return:
#     111     """
# --> 112     candi_prob = {i: self.probability(i) for i in self.candidates(word)}
#     113     sort_candi_prob = sorted(candi_prob.items(), key=operator.itemgetter(1))
#     114     return sort_candi_prob[-1][0]
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/en_spell_corrector.py:112, in <dictcomp>(.0)
#     105 def correct_word(self, word):
#     106     """
#     107     most probable spelling correction for word
#     108     :param word:
#     109     :param mini_prob:
#     110     :return:
#     111     """
# --> 112     candi_prob = {i: self.probability(i) for i in self.candidates(word)}
#     113     sort_candi_prob = sorted(candi_prob.items(), key=operator.itemgetter(1))
#     114     return sort_candi_prob[-1][0]
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/en_spell_corrector.py:94, in EnSpellCorrector.probability(self, word)
#      88 def probability(self, word):
#      89     """
#      90     probability of word
#      91     :param word:
#      92     :return:float
#      93     """
# ---> 94     N = sum(self.word_freq_dict.values())
#      95     return self.word_freq_dict.get(word, 0) / N
#
# AttributeError: 'str' object has no attribute 'values'

# %%
from pycorrector import Corrector
model = Corrector(language_model_path='output_directory/output_model.klm_trigram.klm')
print(model.correct('V EH R II S EH K S II'))
# Out:
# {'source': 'V EH R II S EH K S II', 'target': 'V EH R II S EH K S II', 'errors': []}

# %%
model = Corrector(language_model_path='people2014corpus_chars.klm')
print(model.correct('少先队员因该为老人让坐'))
# Out:
# Downloading data from https://deepspeech.bj.bcebos.com/zh_lm/zh_giga.no_cna_cmn.prune01244.klm
#  973725696/2953395058 [========>.....................] - ETA: 3:38
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 model = Corrector(language_model_path='people2014corpus_chars.klm')
# ----> 2 print(model.correct('少先队员因该为老人让坐'))
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/corrector.py:288, in Corrector.correct(self, sentence, include_symbol, num_fragment, threshold, **kwargs)
#     285 short_sents = split_text_into_sentences_by_symbol(sentence, include_symbol=include_symbol)
#     286 for sent, idx in short_sents:
#     287     # 检错
# --> 288     maybe_errors, proper_details = self._detect(sent, idx, **kwargs)
#     289     for cur_item, begin_idx, end_idx, err_type in maybe_errors:
#     290         # 纠错，逐个处理
#     291         before_sent = sent[:(begin_idx - idx)]
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/detector.py:397, in Detector._detect(self, sentence, start_idx, **kwargs)
#     395 maybe_errors = []
#     396 # 初始化
# --> 397 self.check_detector_initialized()
#     398 # 1. 自定义混淆集加入疑似错误词典
#     399 for confuse in self.custom_confusion:
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/detector.py:151, in Detector.check_detector_initialized(self)
#     149 def check_detector_initialized(self):
#     150     if not self.initialized_detector:
# --> 151         self._initialize_detector()
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/detector.py:109, in Detector._initialize_detector(self)
#     105     filename = self.pretrained_language_models.get(
#     106         self.language_model_path, 'zh_giga.no_cna_cmn.prune01244.klm'
#     107     )
#     108     url = self.pretrained_language_models.get(filename)
# --> 109     self.language_model_path = get_file(
#     110         filename, url, extract=True,
#     111         cache_dir='~',
#     112         cache_subdir=USER_DATA_DIR,
#     113         verbose=1
#     114     )
#     115 self.lm = kenlm.Model(self.language_model_path)
#     117 # 词、频数dict
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/pycorrector/utils/get_file.py:280, in get_file(fname, origin, untar, extract, md5_hash, file_hash, hash_algorithm, archive_format, cache_subdir, cache_dir, verbose)
#     278 try:
#     279     from six.moves.urllib.request import urlretrieve
# --> 280     urlretrieve(origin, fpath, dl_progress)
#     281 except HTTPError as e:
#     282     raise Exception(error_msg.format(origin, e.code, e.msg))
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/urllib/request.py:270, in urlretrieve(url, filename, reporthook, data)
#     267     reporthook(blocknum, bs, size)
#     269 while True:
# --> 270     block = fp.read(bs)
#     271     if not block:
#     272         break
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# !echo "your sentence here" | kenlm/build/bin/query text.binary
# Out:
# /work/van-speech-nlp/jindaznb/jslpnb/torgo_inference_on_cluster/kenlm/util/file.cc:76 in int util::OpenReadOrThrow(const char*) threw ErrnoException because `-1 == (ret = open(name, 00))'.
# No such file or directory while opening text.binary

# %%
# !pip install jamspell
# Out:
# Collecting jamspell
#   Downloading jamspell-0.0.12.tar.gz (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 2.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jamspell
#   Building wheel for jamspell (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [65 lines of output]
#       /work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/dist.py:498: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       running build
#       running build_ext
#       building '_jamspell' extension
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-19rr5eia/jamspell_b091c89d6fcc4e9e930c811b230b4e43/setup.py", line 55, in <module>
#           setup(
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 364, in run
#           self.run_command("build")
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-19rr5eia/jamspell_b091c89d6fcc4e9e930c811b230b4e43/setup.py", line 37, in run
#           self.run_command('build_ext')
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 345, in run
#           self.build_extensions()
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 467, in build_extensions
#           self._build_extensions_serial()
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 493, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 526, in build_extension
#           sources = self.swig_sources(sources, ext)
#         File "/work/van-speech-nlp/jindaznb/asrenv/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 624, in swig_sources
#           swig = self.swig or self.find_swig()
#         File "/tmp/pip-install-19rr5eia/jamspell_b091c89d6fcc4e9e930c811b230b4e43/setup.py", line 50, in find_swig
#           assert subprocess.check_output([swigBinary, "-version"]).find(b'SWIG Version 3') != -1
#       AssertionError
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for jamspell
#   Running setup.py clean for jamspell
# Failed to build jamspell
# ERROR: Could not build wheels for jamspell, which is required to install pyproject.toml-based projects

# %%
# !pip install jamspell
# Out:
# Collecting jamspell
#   Downloading jamspell-0.0.12.tar.gz (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jamspell
#   Building wheel for jamspell (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [52 lines of output]
#       /home/osx/.local/lib/python3.10/site-packages/setuptools/dist.py:770: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running bdist_wheel
#       running build
#       running build_ext
#       building '_jamspell' extension
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-1xvz2hdu/jamspell_dcec735dc32243fabbd89533dbca74ad/setup.py", line 55, in <module>
#           setup(
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/osx/.local/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 325, in run
#           self.run_command("build")
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-1xvz2hdu/jamspell_dcec735dc32243fabbd89533dbca74ad/setup.py", line 37, in run
#           self.run_command('build_ext')
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 346, in run
#           self.build_extensions()
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 468, in build_extensions
#           self._build_extensions_serial()
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 494, in _build_extensions_serial
#           self.build_extension(ext)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 527, in build_extension
#           sources = self.swig_sources(sources, ext)
#         File "/home/osx/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build_ext.py", line 625, in swig_sources
#           swig = self.swig or self.find_swig()
#         File "/tmp/pip-install-1xvz2hdu/jamspell_dcec735dc32243fabbd89533dbca74ad/setup.py", line 49, in find_swig
#           assert swigBinary is not None
#       AssertionError
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for jamspell
#   Running setup.py clean for jamspell
# Failed to build jamspell
# ERROR: Could not build wheels for jamspell, which is required to install pyproject.toml-based projects

# %%
import jamspell

corrector = jamspell.TSpellCorrector()
corrector.LoadLangModel('en.bin')

corrector.FixFragment('I am the begt spell cherken!')
# u'I am the best spell checker!'

# corrector.GetCandidates(['i', 'am', 'the', 'begt', 'spell', 'cherken'], 3)
# # (u'best', u'beat', u'belt', u'bet', u'bent', ... )

# corrector.GetCandidates(['i', 'am', 'the', 'begt', 'spell', 'cherken'], 5)
# # (u'checker', u'chicken', u'checked', u'wherein', u'coherent', ...)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print()
